# %%
from classification import *
import seaborn as sns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11430 entries, 0 to 11429
# Data columns (total 90 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   url                         11430 non-null  object
#  1   length_url                  11430 non-null  int64
#  2   length_hostname             11430 non-null  int64
#  3   ip                          11430 non-null  int64
#  4   nb_dots                     11430 non-null  int64
#  5   nb_hyphens                  11430 non-null  int64
#  6   nb_at                       11430 non-null  int64
#  7   nb_qm                       11430 non-null  int64
#  8   nb_and                      11430 non-null  int64
#  9   nb_or                       11430 non-null  int64
#  10  nb_eq                       11430 non-null  int64
#  11  nb_underscore               11430 non-null  int64
#  12  nb_tilde                    11430 non-null  int64
# ...

# %%
# Gráfico de correlación entre los datos
sns.heatmap(df.corr(),cmap = 'viridis')
# Out:
# C:\Users\Michy S\AppData\Local\Temp\ipykernel_8760\2219860934.py:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <AxesSubplot: >

# %%
# Gráficos de correlación entre todas las columnas
sns.pairplot(df)

# %%
# Gráfico para ver si existen datos faltantes
sns.heatmap(df.isnull(), yticklabels = False, cbar = False, cmap = 'viridis')

# %%
sns.pairplot(df, x_vars= 'ratio_digits_url', y_vars = 'popup_window', hue = 'phishing')

# %%
sns.pairplot(df, x_vars= 'safe_anchor', y_vars = 'links_in_tags',  hue = 'phishing')
